# %% [markdown]
# Outpatient Medical Clinic

# %% [markdown]
# We are a data analyst at an outpatient medical clinic. They offer a wide range of services including consultations, diagnostic tests, minor procedures, and follow-up appointments.

# %%
#Update notebook
#create variables with patient information
name_first = "Albert"
name_last = "Cho"
age = 45
sex = "M"
height_ft = 6.3
weight_lb = 181.39
smoker = False

# %%
#test the data type of the sex variable
type(sex)
# Out:
# str

# %%
#test the data type of the weight variable
type(weight_lb)
# Out:
# float

# %%
#test the data type of smoker status
type(smoker)
# Out:
# bool

# %%
#test the data type of his age
type(age)
# Out:
# int

# %% [markdown]
# Calculate the patient's BMI using the formula from the US center for Disease Control

# %%
#input the variables into the BMI formula and convert the patients height in feet to height in inches
bmi = 703 * (weight_lb/((height_ft*12)**2))
#round the bmi to the nearest hundredths place or two decimal places
bmi = round(bmi,2)
#write a print statement telling Mr. Cho his bmi
print(f'Mr. Cho, you have a Body Mass Index of {bmi}')
# Out:
# Mr. Cho, you have a Body Mass Index of 22.31

# %% [markdown]
# The patient has been diagnosed with a bacterial infection. The formula for an adult amoxicillin dosage is 10mg per kilogrma of body weight rounding to the nearest whole mg. How many mg should be the patient's prescribed dosage?

# %%
#convert the patient's weight to kg
weight_kg=weight_lb*.45
#calculate prescribed dosage according to 10mg per kilogram of patient weight
dosage_mg = weight_kg *10
#round to nearest mg
dosage_mg = round(dosage_mg)
print(f' The patient dosage is {dosage_mg}')
# Out:
#  The patient dosage is 816

# %% [markdown]
# Patients who are between the ages of 40 and 60 should take the above calculated dosage every eight hours for ten days.
#
# Write and run a print statement (using the format feature) that produces an output telling the pharmacist how many total mg of amoxicillin to provide Mr. Cho for the duration of his treatment.

# %%
#calculate total mg of amoxicillin the pharacist should fill for Mr.Cho
total_doses = (24/8)*10
total_dosage = dosage_mg*total_doses
print(f'Provide Mr. Cho with 30 doses of {dosage_mg} mg of amoxicillin or {total_dosage} total mg')
# Out:
# Provide Mr. Cho with 30 doses of 816 mg of amoxicillin or 24480.0 total mg
